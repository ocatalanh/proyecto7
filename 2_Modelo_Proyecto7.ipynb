# %%
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import RandomOverSampler

# %%
# Cargar las variables desde el archivo pickle
with open(r'C:\Users\ocata\OneDrive\Desktop\Proyecto7_DS\models\datos_split_procesados.pkl', 'rb') as f:
    X_train_pca, X_test_pca, y_train, y_test = pickle.load(f)

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_pca, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# # Evaluar el modelo
y_pred = clf.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.67      0.91      0.77        32
#            2       0.25      0.09      0.13        11
#
#     accuracy                           0.64        47
#    macro avg       0.31      0.33      0.30        47
# weighted avg       0.52      0.64      0.56        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Regresion Logistica Multiclase

# %%
# Creamos el clasificador de regresión logística multiclase
logreg_classifier = LogisticRegression(multi_class='auto', max_iter=1000)

# Entrenamos el modelo
logreg_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_logreg = logreg_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (Regresión Logística Multiclase):\n", classification_report(y_test, y_pred_logreg))
# Out:
# Informe de Clasificación (Regresión Logística Multiclase):
#                precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         4
#            1       0.67      0.69      0.68        32
#            2       0.25      0.27      0.26        11
#
#     accuracy                           0.55        47
#    macro avg       0.47      0.40      0.42        47
# weighted avg       0.55      0.55      0.55        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %% [markdown]
# ## Modelo Clasificadores Bayes Ingenuos Gaussianos (Gaussian Naive Bayes)

# %%
# Creamos el clasificador
nb_classifier = GaussianNB()

# Entrenamos el modelo
nb_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_nb = nb_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (Clasificador Bayes Ingenuo Gaussiano):\n", classification_report(y_test, y_pred_nb))
# Out:
# Informe de Clasificación (Clasificador Bayes Ingenuo Gaussiano):
#                precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         4
#            1       0.69      0.75      0.72        32
#            2       0.25      0.18      0.21        11
#
#     accuracy                           0.60        47
#    macro avg       0.48      0.48      0.48        47
# weighted avg       0.57      0.60      0.58        47

# %% [markdown]
# ## Máquinas de Soporte Vectorial (SVM):

# %%
# Creamos el clasificador SVM
svm_classifier = SVC()

# Entrenamos el modelo
svm_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_svm = svm_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (SVM):\n", classification_report(y_test, y_pred_svm))
# Out:
# Informe de Clasificación (SVM):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.67      0.88      0.76        32
#            2       0.20      0.09      0.12        11
#
#     accuracy                           0.62        47
#    macro avg       0.29      0.32      0.29        47
# weighted avg       0.50      0.62      0.54        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Arboles de Decisiones

# %%
# Creamos el clasificador de árboles de decisión
dt_classifier = DecisionTreeClassifier()

# Entrenamos el modelo
dt_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_dt = dt_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (Árboles de Decisión):\n", classification_report(y_test, y_pred_dt))
# Out:
# Informe de Clasificación (Árboles de Decisión):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.63      0.53      0.58        32
#            2       0.24      0.36      0.29        11
#
#     accuracy                           0.45        47
#    macro avg       0.29      0.30      0.29        47
# weighted avg       0.48      0.45      0.46        47

# %% [markdown]
# ## Gradient Boosting Machines (GBM)

# %%
# Creamos el clasificador GBM
gbm_classifier = GradientBoostingClassifier()

# Entrenamos el modelo
gbm_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_gbm = gbm_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (GBM):\n", classification_report(y_test, y_pred_gbm))
# Out:
# Informe de Clasificación (GBM):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.67      0.69      0.68        32
#            2       0.25      0.27      0.26        11
#
#     accuracy                           0.53        47
#    macro avg       0.31      0.32      0.31        47
# weighted avg       0.51      0.53      0.52        47

# %% [markdown]
# ## Redes Neuronales Artificiales (ANN)

# %%
# Creamos el clasificador ANN
ann_classifier = MLPClassifier()

# Entrenamos el modelo
ann_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_ann = ann_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (ANN):\n", classification_report(y_test, y_pred_ann))
# Out:
# Informe de Clasificación (ANN):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.66      0.72      0.69        32
#            2       0.17      0.18      0.17        11
#
#     accuracy                           0.53        47
#    macro avg       0.27      0.30      0.29        47
# weighted avg       0.49      0.53      0.51        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## K Vecinos Más Cercanos (KNN):

# %%
# Creamos el clasificador KNN
knn_classifier = KNeighborsClassifier()

# Entrenamos el modelo
knn_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_knn = knn_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (KNN):\n", classification_report(y_test, y_pred_knn))
# Out:
# Informe de Clasificación (KNN):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.67      0.75      0.71        32
#            2       0.18      0.18      0.18        11
#
#     accuracy                           0.55        47
#    macro avg       0.28      0.31      0.30        47
# weighted avg       0.50      0.55      0.52        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Maquina de Aprendizaje Extremo(ELM)

# %%
# Creamos el clasificador ELM
elm_classifier = GradientBoostingClassifier()

# Entrenamos el modelo
elm_classifier.fit(X_train_pca, y_train)

# Realizamos predicciones en el conjunto de prueba
y_pred_elm = elm_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (ELM):\n", classification_report(y_test, y_pred_elm))
# Out:
# Informe de Clasificación (ELM):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.67      0.69      0.68        32
#            2       0.25      0.27      0.26        11
#
#     accuracy                           0.53        47
#    macro avg       0.31      0.32      0.31        47
# weighted avg       0.51      0.53      0.52        47

# %%
# Definir los valores de los hiperparámetros a probar
param_grid = {'var_smoothing': [1e-9, 1e-8, 1e-7]}

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=GaussianNB(), param_grid=param_grid, cv=5)

# Realizar la búsqueda de cuadrícula en los datos
grid_search.fit(X_train_pca, y_train)

# Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros encontrados:", grid_search.best_params_)

# Realizar predicciones en el conjunto de prueba con el modelo ajustado
y_pred_grid = grid_search.predict(X_test_pca)

# Mostrar el informe de clasificación con los mejores hiperparámetros
print("Informe de Clasificación (Clasificador Bayes Ingenuo Gaussiano con mejores hiperparámetros):\n", classification_report(y_test, y_pred_grid))
# Out:
# Mejores hiperparámetros encontrados: {'var_smoothing': 1e-09}
# Informe de Clasificación (Clasificador Bayes Ingenuo Gaussiano con mejores hiperparámetros):
#                precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         4
#            1       0.69      0.75      0.72        32
#            2       0.25      0.18      0.21        11
#
#     accuracy                           0.60        47
#    macro avg       0.48      0.48      0.48        47
# weighted avg       0.57      0.60      0.58        47

# %%
# Creamos el objeto de muestreo
oversampler = RandomOverSampler(random_state=42)

# Aplicamos el muestreo a los datos de entrenamiento
X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train_pca, y_train)

# %%
# Guardamos los datos de entrenamiento muestreados en un archivo pickle
with open('datos_entrenamiento_muestreados.pickle', 'wb') as f:
    pickle.dump((X_train_resampled, y_train_resampled), f)

# %%
import numpy as np
# Obtenemos los valores únicos y sus conteos
valores_unicos, conteos = np.unique(y_train_resampled, return_counts=True)

# Creamos un diccionario con los valores únicos y sus conteos
diccionario_conteos = dict(zip(valores_unicos, conteos))

print("Conteo de valores:", diccionario_conteos)
# Out:
# Conteo de valores: {0: 107, 1: 107, 2: 107}

# %%
# Crear una nueva instancia del clasificador Gaussiano
nbx_classifier = GaussianNB()

# Entrenar el modelo con los datos de entrenamiento actualizados
nbx_classifier.fit(X_train_resampled , y_train_resampled)
# Out:
# GaussianNB()

# %%
# Realizamos predicciones en el conjunto de prueba
y_pred_nb = nbx_classifier.predict(X_test_pca)

# Mostramos el informe de clasificación
print("Informe de Clasificación (Clasificador Bayes Ingenuo Gaussiano):\n", classification_report(y_test, y_pred_nb))
# Out:
# Informe de Clasificación (Clasificador Bayes Ingenuo Gaussiano):
#                precision    recall  f1-score   support
#
#            0       0.29      0.50      0.36         4
#            1       0.64      0.56      0.60        32
#            2       0.17      0.18      0.17        11
#
#     accuracy                           0.47        47
#    macro avg       0.37      0.41      0.38        47
# weighted avg       0.50      0.47      0.48        47

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_resampled, y_train_resampled)
# # Evaluar el modelo
y_pred = clf.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.71      1.00      0.83        32
#            2       1.00      0.18      0.31        11
#
#     accuracy                           0.72        47
#    macro avg       0.57      0.39      0.38        47
# weighted avg       0.72      0.72      0.64        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Crear el clasificador Random Forest
rf_classifier = RandomForestClassifier(random_state=42)

# Definir la rejilla de hiperparámetros para probar
param_grid = {
    'n_estimators': [100, 200, 300],  # Número de árboles en el bosque
    'max_features': ['auto', 'sqrt', 'log2'],  # Número de características a considerar para la mejor división
    'max_depth': [None, 10, 20, 30],  # Profundidad máxima del árbol
    'min_samples_split': [2, 5, 10],  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [1, 2, 4],  # Número mínimo de muestras requeridas para estar en un nodo hoja
    'bootstrap': [True, False]  # Método para seleccionar muestras para entrenar cada árbol
}

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Realizar la búsqueda de cuadrícula en los datos
grid_search.fit(X_train_resampled, y_train_resampled)

# Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros encontrados:", grid_search.best_params_)

# Realizar predicciones en el conjunto de prueba con el modelo ajustado
y_pred_rf = grid_search.predict(X_test_pca)

# Mostrar el informe de clasificación con los mejores hiperparámetros
print("Informe de Clasificación (Random Forest con mejores hiperparámetros):\n", classification_report(y_test, y_pred_rf))
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 1080 fits failed out of a total of 3240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 918 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 162 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\model_selection\_search.py:1052: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0
nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.79754808 0.81942308 0.81317308 0.80701923 0.81326923 0.825625
#  0.80394231 0.81326923 0.81331731 0.81932692 0.8225     0.82567308
#  0.8225     0.82254808 0.82259615 0.79144231 0.80394231 0.80394231
#  0.80701923 0.81634615 0.81634615 0.80701923 0.81634615 0.81634615
#  0.80081731 0.80701923 0.80706731 0.80076923 0.81326923 0.81639423
#  0.82264423 0.82572115 0.835      0.82259615 0.81014423 0.81322115
#  0.82259615 0.82245192 0.819375   0.81639423 0.831875   0.82875
#  0.81942308 0.81009615 0.81634615 0.80081731 0.80399038 0.80706731
#  0.80081731 0.80399038 0.80706731 0.79447115 0.80394231 0.81019231
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.81634615 0.831875   0.81629808
#  0.81634615 0.81947115 0.831875   0.80384615 0.81629808 0.81942308
#  0.83495192 0.838125   0.84129808 0.81307692 0.81947115 0.81317308
#  0.79461538 0.81009615 0.81634615 0.81644231 0.82259615 0.81634615
#  0.81644231 0.82259615 0.81634615 0.80076923 0.80692308 0.80389423
#  0.81942308 0.81009615 0.82576923 0.81625    0.819375   0.82879808
#  0.81009615 0.81634615 0.81629808 0.81326923 0.82865385 0.8225
#  0.81019231 0.82572115 0.82884615 0.82254808 0.83495192 0.831875
#  0.79153846 0.81024038 0.81653846 0.79153846 0.81024038 0.81653846
#  0.80394231 0.81629808 0.80701923        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.81634615 0.831875   0.81629808 0.81634615 0.81947115 0.831875
#  0.80384615 0.81629808 0.81942308 0.83495192 0.838125   0.84129808
#  0.81620192 0.81947115 0.81317308 0.79461538 0.81009615 0.81634615
#  0.81644231 0.82259615 0.81634615 0.81644231 0.82259615 0.81634615
#  0.80076923 0.80692308 0.80389423 0.81942308 0.81009615 0.82576923
#  0.81625    0.819375   0.82879808 0.81009615 0.81634615 0.81629808
#  0.81326923 0.82865385 0.8225     0.81019231 0.82572115 0.82884615
#  0.82254808 0.83495192 0.831875   0.79153846 0.81024038 0.81653846
#  0.79153846 0.81024038 0.81653846 0.80394231 0.81629808 0.80701923]
#   warnings.warn(
# Mejores hiperparámetros encontrados: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Informe de Clasificación (Random Forest con mejores hiperparámetros):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.70      0.97      0.82        32
#            2       0.67      0.18      0.29        11
#
#     accuracy                           0.70        47
#    macro avg       0.46      0.38      0.37        47
# weighted avg       0.64      0.70      0.62        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Obtener el mejor modelo
best_rf_classifier = grid_search.best_estimator_

# Realizar predicciones en el conjunto de prueba con el modelo ajustado
y_pred_rf = best_rf_classifier.predict(X_test_pca)

# Mostrar el informe de clasificación con los mejores hiperparámetros
print("Informe de Clasificación (Random Forest con mejores hiperparámetros):\n", classification_report(y_test, y_pred_rf))

# (Opcional) Guardar el modelo entrenado para uso futuro
with open(r'C:\Users\ocata\OneDrive\Desktop\Proyecto7_DS\models\mejor_rf_modelo.pkl', 'wb') as f:
    pickle.dump(best_rf_classifier, f)
# Out:
# Informe de Clasificación (Random Forest con mejores hiperparámetros):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.70      0.97      0.82        32
#            2       0.67      0.18      0.29        11
#
#     accuracy                           0.70        47
#    macro avg       0.46      0.38      0.37        47
# weighted avg       0.64      0.70      0.62        47
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ocata\miniconda3\envs\proyecto7\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
